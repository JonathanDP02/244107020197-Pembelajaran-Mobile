# %% [markdown]
# <a href="https://colab.research.google.com/github/JonathanDP02/244107020197-Pembelajaran-Mobile/blob/main/TG1_244107020197_Jonathan_Dwi_Pangestu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyprep scipy wandb pyECG
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# 3. Jelaskan kegunakan masing-masing library tersebut.
#
# Jawaban:
#
# - PyPREP: Digunakan untuk preprocessing sinyal Elektroensefalogram (EEG) secara otomatis, seperti pembersihan noise, filtrasi, dan deteksi saluran (channel) yang rusak.
# - SciPy: Digunakan untuk komputasi ilmiah dan matematika tingkat lanjut, seperti pemrosesan sinyal, aljabar linier, optimasi, dan analisis statistik.
# - wandb (Weights & Biases): Digunakan untuk pelacakan eksperimen Machine Learning / Deep Learning, visualisasi metrik pelatihan, pemantauan hyperparameter, dan kolaborasi tim.
# - pyECG: Digunakan untuk analisis dan pemrosesan sinyal Elektrokardiogram (EKG), termasuk ekstraksi fitur detak jantung dan deteksi gelombang sinyal jantung.

# %% [markdown]
# **Bagian 2**
#
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
#
# Jawaban:
#
# contoh tindakan:
# Membuat dan menyebarkan foto/video deepfake pornografi seseorang menggunakan AI tanpa izin (non-consensual deepfake).
#
# Pelanggaran:
# - Etika: Merusak reputasi, melanggar privasi, serta menyalahgunakan teknologi AI untuk merugikan dan mengeksploitasi orang lain.
# - Hukum: Melanggar Pasal 14 UU No. 12/2022 (UU TPKS) dan Pasal 27 ayat (1) UU ITE No. 1/2024 terkait penyebaran konten bermuatan seksual hasil rekayasa elektronik tanpa persetujuan.
#
# Referensi:
# - UU No. 12 Tahun 2022 (TPKS)
# - UU No. 1 Tahun 2024 (ITE)
# - SE Menkominfo No. 9 Tahun 2023 (Etika AI)

# %% [markdown]
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# jawaban:
#
# - Dampak Energi: Proses pelatihan (training) dan pemrosesan (inference) model AI mengonsumsi listrik dalam jumlah masif. Hal ini meningkatkan emisi karbon secara signifikan jika sumber listriknya masih bergantung pada bahan bakar fosil.
# - Dampak Lingkungan: Pusat data membutuhkan jutaan liter air bersih untuk sistem pendingin (cooling system) mesin pendingin server, yang dapat memicu kelangkaan air di wilayah sekitar data center. selain itu, tingginya pergantian hardware GPU/CPU juga mempercepat penumpukan limbah elektronik (e-waste).
#
# cara mengatasinya:
#
# - Efisiensi Model & Algoritma: Menggunakan teknik seperti quantization, pruning, dan knowledge distillation agar model AI lebih ringan dan efisien saat dijalankan tanpa harus mengorbankan akurasi secara drastis.
#
# - Peralihan ke Energi Terbarukan: Mengoperasikan pusat data menggunakan sumber energi bersih seperti panel surya, angin, atau hidroelektrik, serta menerapkan sistem pendingin ramah lingkungan (liquid cooling tertutup).
#
# - Pengoptimasian Hardware: Memilih infrastruktur komputasi yang memang dirancang khusus untuk efisiensi daya
#
# pendapat pribadi:
# Menurut saya, AI tidak boleh hanya dipandang sebagai konsumen energi, melainkan juga harus dimanfaatkan sebagai solusi iklim (AI for Sustainability). Pengembangan AI skala besar harus menerapkan prinsip Green AI, di mana konsumsi daya menjadi metrik utama yang dievaluasi bersamaan dengan tingkat akurasi model. Selain itu, regulasi pemerintah dan kesadaran pengembang untuk memilih penyedia cloud berbasis energi terbarukan sangat krusial agar inovasi teknologi tidak merusak keberlanjutan lingkungan.
#
# referensi:
# - Strubell, E., Ganesh, A., & McCallum, A. (2019). Energy and Policy Considerations for Deep Learning in NLP. Association for Computational Linguistics (ACL).
# - Patterson, D., et al. (2021). The Carbon Footprint of Machine Learning Training Will Planarize, Then Decline. IEEE Micro.
# - UNESCO (2021). Recommendation on the Ethics of Artificial Intelligence (Prinsip Lingkungan dan Keberlanjutan).
